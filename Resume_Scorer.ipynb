# %%
#!pip install pypdf
#!pip install pdf2image
#brew install poppler
#!pip install pytesseract

# %%
import cv2
from glob import glob
from langchain_openai import OpenAIEmbeddings
import numpy as np
import pandas as pd
from pdf2image import convert_from_path
import pickle
from pypdf import PdfReader 
import pytesseract
import re
import os
from sklearn.metrics.pairwise import cosine_similarity

# %%
JD_PATH = "jd_data/*"
RESUME_PATH = "resume_data/*/*"
OPENAI_API_KEY = "API-KEY"
EMBEDDING_MODEL_NAME = "text-embedding-3-large"
OUTPUT_PATH = "output/"

JD_EMBEDDINGS_FILENAME = "jd_embeddings_large.pkl"
RESUME_EMBEDDINGS_FILENAME = "resume_embeddings_large.pkl"

# %%
# Refer Readme File for additional details, Change the file paths accordingly
poppler_path = r'D:\Apps\Release-24.07.0-0\poppler-24.07.0\Library\bin'
# Update the path to the location where Tesseract is installed
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
class DirectoryReader:
    def __init__(self, path_to_jds, path_to_resumes):
        self.path_to_jds = path_to_jds
        self.path_to_resumes = path_to_resumes
        self.jd_data = {}
        self.resume_data = {}
        
    def read_jd_files(self):
        file_list = glob(self.path_to_jds, recursive = True)
        for file in file_list:
            with open(file, "r", encoding="utf-8") as f:
                data = f.read()
                data = data.strip().lower()
                job_name = file.split("/")[-1].replace(".txt", "")
                # print(file, job_name)
                self.jd_data[job_name] = data
        return self.jd_data
    
    def read_resume_files(self):
        file_list = glob(self.path_to_resumes, recursive = True)
        for file in file_list:
            print(file)
            reader = PdfReader(file)
            data = ""
            for page in reader.pages:
                data = data + page.extract_text() + "\n"
            data = data.strip().lower()
            
            
            # job_title = file.split("/")[1].replace(" ", "_").lower()
            # resume_name = file.split("/")[2].replace("-", "_").lower().replace(".pdf", "")

            file_parts = os.path.normpath(file).split(os.sep)

            # The job title would be the name of the directory just before the file name
            job_title = file_parts[-2].replace(" ", "_").lower()
            
            # The resume name would be the file name without the extension
            resume_name = os.path.basename(file_parts[-1]).replace("-", "_").lower().replace(".pdf", "")    

            if len(data) > 1:
                self.resume_data[job_title + "_" + resume_name] = data
            else: #to solve for incorrect startxref pointer(3), since they are images in pdf
                pages = convert_from_path(file, poppler_path=poppler_path)
                extracted_text = []
                for page in pages:
                    # Step 1: Preprocess the image (deskew)
                    preprocessed_image = self.deskew(np.array(page))
                    # Step 2: Extract text using OCR
                    text = self.extract_text_from_image(preprocessed_image)
                    extracted_text.append(text)
                self.resume_data[job_title + "_" + resume_name] = "\n".join(extracted_text).strip().lower()
        return self.resume_data
    
    def deskew(self, image):
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        gray = cv2.bitwise_not(gray)
        coords = np.column_stack(np.where(gray > 0))
        angle = cv2.minAreaRect(coords)[-1]

        if angle < -45:
            angle = -(90 + angle)
        else:
            angle = -angle

        (h, w) = image.shape[:2]
        center = (w // 2, h // 2)
        M = cv2.getRotationMatrix2D(center, angle, 1.0)
        rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
        return rotated
    
    def extract_text_from_image(self, image):
        text = pytesseract.image_to_string(image)
        return text

# %%
dir_reader = DirectoryReader(JD_PATH, RESUME_PATH)

# %%
jd_data = dir_reader.read_jd_files()
resume_data = dir_reader.read_resume_files()
# Out:
# incorrect startxref pointer(3)
# resume_data\Big Data Analyst\resume-1.pdf
# resume_data\Big Data Analyst\resume-2.pdf
# resume_data\Big Data Analyst\resume-3.pdf
# resume_data\Business Intelligence Analyst\resume-10.pdf
# resume_data\Business Intelligence Analyst\resume-11.pdf
# resume_data\Business Intelligence Analyst\resume-12.pdf
# resume_data\Business Intelligence Analyst\resume-13.pdf
# resume_data\Business Intelligence Analyst\resume-4.pdf
# incorrect startxref pointer(3)
# resume_data\Business Intelligence Analyst\resume-5.pdf
# resume_data\Business Intelligence Analyst\resume-6.pdf
# incorrect startxref pointer(3)
# resume_data\Business Intelligence Analyst\resume-7.pdf
# resume_data\Business Intelligence Analyst\resume-8.pdf
# resume_data\Business Intelligence Analyst\resume-9.pdf
# resume_data\Data Analyst\resume-14.pdf
# resume_data\Data Analyst\resume-15.pdf
# resume_data\Data Analyst\resume-16.pdf
# resume_data\Data Analyst\resume-17.pdf
# resume_data\Data Analyst\resume-18.pdf
# resume_data\Data Analyst\resume-19.pdf
# resume_data\Data Analyst\resume-20.pdf
# resume_data\Data Analyst\resume-21.pdf
# resume_data\Data Analyst\resume-22.pdf
# resume_data\Data Analyst\resume-23.pdf
# resume_data\Data Analyst\resume-24.pdf
# resume_data\Data Analyst\resume-25.pdf
# resume_data\Data Analyst\resume-26.pdf
# resume_data\Data Analyst\resume-27.pdf
# resume_data\Data Analyst\resume-28.pdf
# resume_data\Data Architect\resume-29.pdf
# incorrect startxref pointer(3)
# resume_data\Data Architect\resume-30.pdf
# incorrect startxref pointer(3)
# resume_data\Data Architect\resume-31.pdf
# resume_data\Data Architect\resume-32.pdf
# resume_data\Data Architect\resume-33.pdf
# resume_data\Data Architect\resume-34.pdf
# resume_data\Data Architect\resume-35.pdf
# resume_data\Data Architect\resume-36.pdf
# resume_data\Data Architect\resume-37.pdf
# resume_data\Data Architect\resume-38.pdf
# resume_data\Data Architect\resume-39.pdf
# resume_data\Data Engineer\resume-40.pdf
# resume_data\Data Engineer\resume-41.pdf
# resume_data\Data Engineer\resume-42.pdf
# resume_data\Data Engineer\resume-43.pdf
# resume_data\Data Engineer\resume-44.pdf
# resume_data\Data Engineer\resume-45.pdf
# resume_data\Data Engineer\resume-46.pdf
# resume_data\Data Engineer\resume-47.pdf
# resume_data\Data Engineer\resume-48.pdf
# resume_data\Data Engineer\resume-49.pdf
# resume_data\Data Engineer\resume-50.pdf
# resume_data\Data Engineer\resume-51.pdf
# resume_data\Data Engineer\resume-52.pdf
# resume_data\Data Engineer\resume-53.pdf
# resume_data\Data Scientist\resume-54.pdf
# resume_data\Data Scientist\resume-55.pdf
# resume_data\Data Scientist\resume-56.pdf
# resume_data\Data Scientist\resume-57.pdf
# resume_data\Data Scientist\resume-58.pdf
# resume_data\Data Scientist\resume-59.pdf
# resume_data\Data Scientist\resume-60.pdf
# resume_data\Data Scientist\resume-61.pdf
# resume_data\Data Scientist\resume-62.pdf
# resume_data\Data Scientist\resume-63.pdf
# resume_data\Data Scientist\resume-64.pdf
# resume_data\Data Scientist\resume-65.pdf
# resume_data\Data Scientist\resume-66.pdf
# resume_data\Data Scientist\resume-67.pdf
# resume_data\Data Scientist\resume-68.pdf
# resume_data\Data Scientist\resume-69.pdf
# resume_data\Data Scientist\resume-70.pdf
# resume_data\Data Scientist\resume-71.pdf
# incorrect startxref pointer(3)
# resume_data\Data Scientist\resume-72.pdf
# resume_data\Machine Learning Engineer\resume-73.pdf
# incorrect startxref pointer(3)
# resume_data\Machine Learning Engineer\resume-74.pdf
# incorrect startxref pointer(3)
# resume_data\Machine Learning Engineer\resume-75.pdf
# resume_data\Machine Learning Engineer\resume-76.pdf
# resume_data\Machine Learning Engineer\resume-77.pdf
# resume_data\Machine Learning Engineer\resume-78.pdf
# resume_data\Machine Learning Engineer\resume-79.pdf
# resume_data\Machine Learning Engineer\resume-80.pdf
# resume_data\Machine Learning Engineer\resume-81.pdf
# resume_data\Machine Learning Engineer\resume-82.pdf
# resume_data\Machine Learning Engineer\resume-83.pdf
# resume_data\MLOps Engineer\resume-84.pdf
# resume_data\MLOps Engineer\resume-85.pdf
# resume_data\MLOps Engineer\resume-86.pdf
# resume_data\MLOps Engineer\resume-87.pdf
# resume_data\MLOps Engineer\resume-88.pdf

# %%
print("Number of JDs -> ", len(jd_data))
print("Number of Resumes -> ", len(resume_data))
# Out:
# Number of JDs ->  32
# Number of Resumes ->  88

# %%
class EmbeddingModel:
    def __init__(self):
        self.embedding_model = OpenAIEmbeddings(api_key=OPENAI_API_KEY, model=EMBEDDING_MODEL_NAME)
        
    def get_embeddings(self, data_dict):
        output_dict = {}
        keys = list(data_dict.keys())
        values = list(data_dict.values())
        embeddings = self.embedding_model.embed_documents(values)
        for i in range(0, len(keys)):
            output_dict[keys[i]] = embeddings[i]
        return output_dict
        
    def save_embeddings(self, embedding, file_name):
        with open(OUTPUT_PATH + file_name, 'wb') as handle:
            pickle.dump(embedding, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
    def read_embeddings(self, file_name):
        with open(OUTPUT_PATH + file_name, 'rb') as handle:
            output_dict = pickle.load(handle)
        return output_dict

# %%
embedding_model = EmbeddingModel()

# %%
#Generate and Save JD Embeddings
jd_embeddings = embedding_model.get_embeddings(jd_data)
embedding_model.save_embeddings(jd_embeddings, JD_EMBEDDINGS_FILENAME)

# %%
#Generate and Save Resume Embeddings
resume_embeddings = embedding_model.get_embeddings(resume_data)
embedding_model.save_embeddings(resume_embeddings, RESUME_EMBEDDINGS_FILENAME)

# %% [markdown]
# ### Read Embeddings

# %%
jd_embeddings = embedding_model.read_embeddings(JD_EMBEDDINGS_FILENAME)
resume_embeddings = embedding_model.read_embeddings(RESUME_EMBEDDINGS_FILENAME)

# %% [markdown]
# ### Calculate cosine similarity

# %%
resume_jd_combi_to_match = {"data_engineer": "de", "data_analyst": "dataanalyst", 
                            "big_data_analyst": "bigdataanalyst", 
                           "mlops_engineer": "mlops", "data_scientist": "ds", "data_architect": "da",
                           "machine_learning_engineer": "mle", "business_intelligence_analyst": "bianalyst"}

jd_pattern = re.compile(r'\d+_[a-z]+$')
resume_pattern = re.compile(r'_resume_\d+$')

# %%
SIMILARITY_DICT = {}
for key1 in jd_embeddings.keys():

    for key2 in resume_embeddings.keys():
  
        cleaned_jd_category = jd_pattern.sub('', key1).replace('jd_data\\', '').replace('jd_data/', '')
        print("JD", cleaned_jd_category)
        cleaned_resume_category = resume_pattern.sub('', key2)
        print("Res", cleaned_resume_category)
        if resume_jd_combi_to_match[cleaned_resume_category] == cleaned_jd_category:
            sim_score = cosine_similarity(np.array(jd_embeddings[key1]).reshape(1, -1), 
                                          np.array(resume_embeddings[key2]).reshape(1, -1))[0][0]
            print(sim_score)
            if key2 not in SIMILARITY_DICT.keys():
                SIMILARITY_DICT[key2] = {}
            SIMILARITY_DICT[key2][key1] = {"score": sim_score}
        else:
            continue
# Out:
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res business_intelligence_analyst
# 0.5060060482967327
# JD bianalyst
# Res business_intelligence_analyst
# 0.5384419551283793
# JD bianalyst
# Res business_intelligence_analyst
# 0.49280038579932084
# JD bianalyst
# Res business_intelligence_analyst
# 0.4152638537615121
# JD bianalyst
# Res business_intelligence_analyst
# 0.4456743295315385
# JD bianalyst
# Res business_intelligence_analyst
# 0.433608582893469
# JD bianalyst
# Res business_intelligence_analyst
# 0.5355024951759682
# JD bianalyst
# Res business_intelligence_analyst
# 0.5115681493032047
# JD bianalyst
# Res business_intelligence_analyst
# 0.5070309571995366
# JD bianalyst
# Res business_intelligence_analyst
# 0.44577086621022755
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res business_intelligence_analyst
# 0.4516332687857284
# JD bianalyst
# Res business_intelligence_analyst
# 0.46185597321058647
# JD bianalyst
# Res business_intelligence_analyst
# 0.42029537237885944
# JD bianalyst
# Res business_intelligence_analyst
# 0.4357916155528451
# JD bianalyst
# Res business_intelligence_analyst
# 0.43023611994143157
# JD bianalyst
# Res business_intelligence_analyst
# 0.44241893853564207
# JD bianalyst
# Res business_intelligence_analyst
# 0.4773332238561173
# JD bianalyst
# Res business_intelligence_analyst
# 0.4647580912583215
# JD bianalyst
# Res business_intelligence_analyst
# 0.48320704693679795
# JD bianalyst
# Res business_intelligence_analyst
# 0.4245331705357621
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res business_intelligence_analyst
# 0.5401182373469351
# JD bianalyst
# Res business_intelligence_analyst
# 0.551431460418887
# JD bianalyst
# Res business_intelligence_analyst
# 0.5578922269611359
# JD bianalyst
# Res business_intelligence_analyst
# 0.5000933090181511
# JD bianalyst
# Res business_intelligence_analyst
# 0.5157608082293603
# JD bianalyst
# Res business_intelligence_analyst
# 0.5111411624594357
# JD bianalyst
# Res business_intelligence_analyst
# 0.6269988362841541
# JD bianalyst
# Res business_intelligence_analyst
# 0.5704051011714497
# JD bianalyst
# Res business_intelligence_analyst
# 0.6187611585535172
# JD bianalyst
# Res business_intelligence_analyst
# 0.4760047273328329
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res big_data_analyst
# JD bianalyst
# Res business_intelligence_analyst
# 0.53051803638707
# JD bianalyst
# Res business_intelligence_analyst
# 0.5176161554003633
# JD bianalyst
# Res business_intelligence_analyst
# 0.5198985619305732
# JD bianalyst
# Res business_intelligence_analyst
# 0.4671302067009403
# JD bianalyst
# Res business_intelligence_analyst
# 0.5038370828368701
# JD bianalyst
# Res business_intelligence_analyst
# 0.4932325533017267
# JD bianalyst
# Res business_intelligence_analyst
# 0.5801570051491428
# JD bianalyst
# Res business_intelligence_analyst
# 0.5369369971176661
# JD bianalyst
# Res business_intelligence_analyst
# 0.5646706880613569
# JD bianalyst
# Res business_intelligence_analyst
# 0.49617361861820897
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_analyst
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_architect
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_engineer
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res data_scientist
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res machine_learning_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bianalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res big_data_analyst
# 0.5027253443706718
# JD bigdataanalyst
# Res big_data_analyst
# 0.44728028796092045
# JD bigdataanalyst
# Res big_data_analyst
# 0.4350959713152389
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res big_data_analyst
# 0.472244060680288
# JD bigdataanalyst
# Res big_data_analyst
# 0.42596329823004647
# JD bigdataanalyst
# Res big_data_analyst
# 0.38445983506288817
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res big_data_analyst
# 0.5420341044322824
# JD bigdataanalyst
# Res big_data_analyst
# 0.4714576288618213
# JD bigdataanalyst
# Res big_data_analyst
# 0.4513962158798478
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res big_data_analyst
# 0.5563235144955632
# JD bigdataanalyst
# Res big_data_analyst
# 0.472820630735203
# JD bigdataanalyst
# Res big_data_analyst
# 0.47204999461905095
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res business_intelligence_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_analyst
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_architect
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_engineer
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res data_scientist
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res machine_learning_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD bigdataanalyst
# Res mlops_engineer
# JD da
# Res big_data_analyst
# JD da
# Res big_data_analyst
# JD da
# Res big_data_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_architect
# 0.5666831386084783
# JD da
# Res data_architect
# 0.5502090361171983
# JD da
# Res data_architect
# 0.548726634441312
# JD da
# Res data_architect
# 0.556515203357387
# JD da
# Res data_architect
# 0.5569299233693445
# JD da
# Res data_architect
# 0.6207766205426046
# JD da
# Res data_architect
# 0.5669990351024459
# JD da
# Res data_architect
# 0.4915459668452435
# JD da
# Res data_architect
# 0.4675127574713124
# JD da
# Res data_architect
# 0.49372210229923413
# JD da
# Res data_architect
# 0.6474229166550821
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res big_data_analyst
# JD da
# Res big_data_analyst
# JD da
# Res big_data_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_architect
# 0.4926840907873853
# JD da
# Res data_architect
# 0.4648827546115097
# JD da
# Res data_architect
# 0.5230508301133687
# JD da
# Res data_architect
# 0.4874255065846048
# JD da
# Res data_architect
# 0.47112134837717506
# JD da
# Res data_architect
# 0.5496515524783232
# JD da
# Res data_architect
# 0.4699812662848733
# JD da
# Res data_architect
# 0.4098780569078402
# JD da
# Res data_architect
# 0.4714593431328588
# JD da
# Res data_architect
# 0.4413954230384296
# JD da
# Res data_architect
# 0.5290097695767986
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res big_data_analyst
# JD da
# Res big_data_analyst
# JD da
# Res big_data_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_architect
# 0.5113844044816547
# JD da
# Res data_architect
# 0.4784074911241193
# JD da
# Res data_architect
# 0.4830155534983681
# JD da
# Res data_architect
# 0.5354757431792296
# JD da
# Res data_architect
# 0.5136129028055993
# JD da
# Res data_architect
# 0.5458309479341683
# JD da
# Res data_architect
# 0.5094191613869162
# JD da
# Res data_architect
# 0.37403779956087124
# JD da
# Res data_architect
# 0.3914545062981042
# JD da
# Res data_architect
# 0.3725942421706804
# JD da
# Res data_architect
# 0.5770738715003141
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res big_data_analyst
# JD da
# Res big_data_analyst
# JD da
# Res big_data_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res business_intelligence_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_analyst
# JD da
# Res data_architect
# 0.5123647871227677
# JD da
# Res data_architect
# 0.5140138459978775
# JD da
# Res data_architect
# 0.4943945855441806
# JD da
# Res data_architect
# 0.5126365128061443
# JD da
# Res data_architect
# 0.540853956687757
# JD da
# Res data_architect
# 0.6020888550541936
# JD da
# Res data_architect
# 0.5098821108703588
# JD da
# Res data_architect
# 0.42495149395385723
# JD da
# Res data_architect
# 0.41903446811880884
# JD da
# Res data_architect
# 0.4480055281581107
# JD da
# Res data_architect
# 0.6007707936011906
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_engineer
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res data_scientist
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res machine_learning_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD da
# Res mlops_engineer
# JD dataanalyst
# Res big_data_analyst
# JD dataanalyst
# Res big_data_analyst
# JD dataanalyst
# Res big_data_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res data_analyst
# 0.4448697175606732
# JD dataanalyst
# Res data_analyst
# 0.44790332303153235
# JD dataanalyst
# Res data_analyst
# 0.40278237878527656
# JD dataanalyst
# Res data_analyst
# 0.44229633394358714
# JD dataanalyst
# Res data_analyst
# 0.4499432059430297
# JD dataanalyst
# Res data_analyst
# 0.4993896251531412
# JD dataanalyst
# Res data_analyst
# 0.4614672595855522
# JD dataanalyst
# Res data_analyst
# 0.46414604871336523
# JD dataanalyst
# Res data_analyst
# 0.43766943475662
# JD dataanalyst
# Res data_analyst
# 0.4563681985223201
# JD dataanalyst
# Res data_analyst
# 0.3921676934904974
# JD dataanalyst
# Res data_analyst
# 0.44195972147381596
# JD dataanalyst
# Res data_analyst
# 0.45417811668312186
# JD dataanalyst
# Res data_analyst
# 0.40992795886548594
# JD dataanalyst
# Res data_analyst
# 0.4464389192907293
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res big_data_analyst
# JD dataanalyst
# Res big_data_analyst
# JD dataanalyst
# Res big_data_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res data_analyst
# 0.5735232354659899
# JD dataanalyst
# Res data_analyst
# 0.5295708158488817
# JD dataanalyst
# Res data_analyst
# 0.49414910144180435
# JD dataanalyst
# Res data_analyst
# 0.5307969220424337
# JD dataanalyst
# Res data_analyst
# 0.5383075038047451
# JD dataanalyst
# Res data_analyst
# 0.5678987063059528
# JD dataanalyst
# Res data_analyst
# 0.5351289120009702
# JD dataanalyst
# Res data_analyst
# 0.5231906718260392
# JD dataanalyst
# Res data_analyst
# 0.5465098197708446
# JD dataanalyst
# Res data_analyst
# 0.5544650183203242
# JD dataanalyst
# Res data_analyst
# 0.48648996119423293
# JD dataanalyst
# Res data_analyst
# 0.5580652147991167
# JD dataanalyst
# Res data_analyst
# 0.5620308740651206
# JD dataanalyst
# Res data_analyst
# 0.49591994530098815
# JD dataanalyst
# Res data_analyst
# 0.5315471167480988
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res mlops_engineer
# JD dataanalyst
# Res big_data_analyst
# JD dataanalyst
# Res big_data_analyst
# JD dataanalyst
# Res big_data_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res business_intelligence_analyst
# JD dataanalyst
# Res data_analyst
# 0.5112386743122367
# JD dataanalyst
# Res data_analyst
# 0.48538993902828664
# JD dataanalyst
# Res data_analyst
# 0.44296315070603853
# JD dataanalyst
# Res data_analyst
# 0.4926590983978719
# JD dataanalyst
# Res data_analyst
# 0.5090329489977852
# JD dataanalyst
# Res data_analyst
# 0.53958616818929
# JD dataanalyst
# Res data_analyst
# 0.4884359201956699
# JD dataanalyst
# Res data_analyst
# 0.4876628595835262
# JD dataanalyst
# Res data_analyst
# 0.48120388723817337
# JD dataanalyst
# Res data_analyst
# 0.5027642552991766
# JD dataanalyst
# Res data_analyst
# 0.45605250806374265
# JD dataanalyst
# Res data_analyst
# 0.5182163978066374
# JD dataanalyst
# Res data_analyst
# 0.5109391384604396
# JD dataanalyst
# Res data_analyst
# 0.46403593957212547
# JD dataanalyst
# Res data_analyst
# 0.5040448191679006
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_architect
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_engineer
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res data_scientist
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# JD dataanalyst
# Res machine_learning_engineer
# ...
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res machine_learning_engineer
# 0.47701498136402143
# JD mle
# Res machine_learning_engineer
# 0.4824955667851626
# JD mle
# Res machine_learning_engineer
# 0.5126695239991192
# JD mle
# Res machine_learning_engineer
# 0.501256322561402
# JD mle
# Res machine_learning_engineer
# 0.5267852240119937
# JD mle
# Res machine_learning_engineer
# 0.4795054999508735
# JD mle
# Res machine_learning_engineer
# 0.4158450385850996
# JD mle
# Res machine_learning_engineer
# 0.4588706244673295
# JD mle
# Res machine_learning_engineer
# 0.44032153817407804
# JD mle
# Res machine_learning_engineer
# 0.4829946476189655
# JD mle
# Res machine_learning_engineer
# 0.47453669093046136
# JD mle
# Res mlops_engineer
# JD mle
# Res mlops_engineer
# JD mle
# Res mlops_engineer
# JD mle
# Res mlops_engineer
# JD mle
# Res mlops_engineer
# JD mle
# Res big_data_analyst
# JD mle
# Res big_data_analyst
# JD mle
# Res big_data_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res business_intelligence_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_analyst
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_architect
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_engineer
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res data_scientist
# JD mle
# Res machine_learning_engineer
# 0.4861774805279183
# JD mle
# Res machine_learning_engineer
# 0.5442152374627323
# JD mle
# Res machine_learning_engineer
# 0.5236616227842043
# JD mle
# Res machine_learning_engineer
# 0.5253352172231057
# JD mle
# Res machine_learning_engineer
# 0.5568585443706316
# JD mle
# Res machine_learning_engineer
# 0.5494185868646504
# JD mle
# Res machine_learning_engineer
# 0.42498521225250996
# JD mle
# Res machine_learning_engineer
# 0.4849274070584054
# JD mle
# Res machine_learning_engineer
# 0.43977300632260263
# JD mle
# Res machine_learning_engineer
# 0.5068100143300269
# JD mle
# Res machine_learning_engineer
# 0.5322501041820281
# JD mle
# Res mlops_engineer
# JD mle
# Res mlops_engineer
# JD mle
# Res mlops_engineer
# JD mle
# Res mlops_engineer
# JD mle
# Res mlops_engineer
# JD mlops
# Res big_data_analyst
# JD mlops
# Res big_data_analyst
# JD mlops
# Res big_data_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res mlops_engineer
# 0.4641761131491343
# JD mlops
# Res mlops_engineer
# 0.5384066383172775
# JD mlops
# Res mlops_engineer
# 0.5016286331154144
# JD mlops
# Res mlops_engineer
# 0.5057189169488647
# JD mlops
# Res mlops_engineer
# 0.45922924082396177
# JD mlops
# Res big_data_analyst
# JD mlops
# Res big_data_analyst
# JD mlops
# Res big_data_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res mlops_engineer
# 0.37027898603064047
# JD mlops
# Res mlops_engineer
# 0.40056777498455276
# JD mlops
# Res mlops_engineer
# 0.36542323630718104
# JD mlops
# Res mlops_engineer
# 0.4527814152085251
# JD mlops
# Res mlops_engineer
# 0.3754415930595549
# JD mlops
# Res big_data_analyst
# JD mlops
# Res big_data_analyst
# JD mlops
# Res big_data_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res mlops_engineer
# 0.4684204674371508
# JD mlops
# Res mlops_engineer
# 0.49212325564951986
# JD mlops
# Res mlops_engineer
# 0.45483953237425867
# JD mlops
# Res mlops_engineer
# 0.46399144296461636
# JD mlops
# Res mlops_engineer
# 0.4405087566504825
# JD mlops
# Res big_data_analyst
# JD mlops
# Res big_data_analyst
# JD mlops
# Res big_data_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res business_intelligence_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_analyst
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_architect
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_engineer
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res data_scientist
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res machine_learning_engineer
# JD mlops
# Res mlops_engineer
# 0.4576278008524991
# JD mlops
# Res mlops_engineer
# 0.597630881525427
# JD mlops
# Res mlops_engineer
# 0.5392066130015547
# JD mlops
# Res mlops_engineer
# 0.4721335459153845
# JD mlops
# Res mlops_engineer
# 0.44024273677226755

# %%
def get_top_matching_job(resume_name):
    score_list = [[key, SIMILARITY_DICT[resume_name][key]['score']] 
                  for key in SIMILARITY_DICT[resume_name].keys()]
    score_list = sorted(score_list, key=lambda x: x[1], reverse=True)
    return score_list[0]

# %%
get_top_matching_job("big_data_analyst_resume_1")
# Out:
# ['jd_data\\bigdataanalyst4_quess', 0.5563235144955632]

# %%
output = []
for key in SIMILARITY_DICT.keys():
    top_matching_job = get_top_matching_job(key)
    output.append([key, top_matching_job[0], int(round(top_matching_job[1] * 100.0))])
    print("Resume Name: ", key, "\nJD Name: ", top_matching_job[0], 
          "\nMatching Score: ", int(round(top_matching_job[1] * 100.0)))
    print("----------")
# Out:
# Resume Name:  business_intelligence_analyst_resume_10
# JD Name:  jd_data\bianalyst3_nicbl
# Matching Score:  54
# ----------
# Resume Name:  business_intelligence_analyst_resume_11
# JD Name:  jd_data\bianalyst3_nicbl
# Matching Score:  55
# ----------
# Resume Name:  business_intelligence_analyst_resume_12
# JD Name:  jd_data\bianalyst3_nicbl
# Matching Score:  56
# ----------
# Resume Name:  business_intelligence_analyst_resume_13
# JD Name:  jd_data\bianalyst3_nicbl
# Matching Score:  50
# ----------
# Resume Name:  business_intelligence_analyst_resume_4
# JD Name:  jd_data\bianalyst3_nicbl
# Matching Score:  52
# ----------
# Resume Name:  business_intelligence_analyst_resume_5
# JD Name:  jd_data\bianalyst3_nicbl
# Matching Score:  51
# ----------
# Resume Name:  business_intelligence_analyst_resume_6
# JD Name:  jd_data\bianalyst3_nicbl
# Matching Score:  63
# ----------
# Resume Name:  business_intelligence_analyst_resume_7
# JD Name:  jd_data\bianalyst3_nicbl
# Matching Score:  57
# ----------
# Resume Name:  business_intelligence_analyst_resume_8
# JD Name:  jd_data\bianalyst3_nicbl
# Matching Score:  62
# ----------
# Resume Name:  business_intelligence_analyst_resume_9
# JD Name:  jd_data\bianalyst4_rocketlane
# Matching Score:  50
# ----------
# Resume Name:  big_data_analyst_resume_1
# JD Name:  jd_data\bigdataanalyst4_quess
# Matching Score:  56
# ----------
# Resume Name:  big_data_analyst_resume_2
# JD Name:  jd_data\bigdataanalyst4_quess
# Matching Score:  47
# ----------
# Resume Name:  big_data_analyst_resume_3
# JD Name:  jd_data\bigdataanalyst4_quess
# Matching Score:  47
# ----------
# Resume Name:  data_architect_resume_29
# JD Name:  jd_data\da1_rakuten
# Matching Score:  57
# ----------
# Resume Name:  data_architect_resume_30
# JD Name:  jd_data\da1_rakuten
# Matching Score:  55
# ----------
# Resume Name:  data_architect_resume_31
# JD Name:  jd_data\da1_rakuten
# Matching Score:  55
# ----------
# Resume Name:  data_architect_resume_32
# JD Name:  jd_data\da1_rakuten
# Matching Score:  56
# ----------
# Resume Name:  data_architect_resume_33
# JD Name:  jd_data\da1_rakuten
# Matching Score:  56
# ----------
# Resume Name:  data_architect_resume_34
# JD Name:  jd_data\da1_rakuten
# Matching Score:  62
# ----------
# Resume Name:  data_architect_resume_35
# JD Name:  jd_data\da1_rakuten
# Matching Score:  57
# ----------
# Resume Name:  data_architect_resume_36
# JD Name:  jd_data\da1_rakuten
# Matching Score:  49
# ----------
# Resume Name:  data_architect_resume_37
# JD Name:  jd_data\da2_schneider
# Matching Score:  47
# ----------
# Resume Name:  data_architect_resume_38
# JD Name:  jd_data\da1_rakuten
# Matching Score:  49
# ----------
# Resume Name:  data_architect_resume_39
# JD Name:  jd_data\da1_rakuten
# Matching Score:  65
# ----------
# Resume Name:  data_analyst_resume_14
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  57
# ----------
# Resume Name:  data_analyst_resume_15
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  53
# ----------
# Resume Name:  data_analyst_resume_16
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  49
# ----------
# Resume Name:  data_analyst_resume_17
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  53
# ----------
# Resume Name:  data_analyst_resume_18
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  54
# ----------
# Resume Name:  data_analyst_resume_19
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  57
# ----------
# Resume Name:  data_analyst_resume_20
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  54
# ----------
# Resume Name:  data_analyst_resume_21
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  52
# ----------
# Resume Name:  data_analyst_resume_22
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  55
# ----------
# Resume Name:  data_analyst_resume_23
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  55
# ----------
# Resume Name:  data_analyst_resume_24
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  49
# ----------
# Resume Name:  data_analyst_resume_25
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  56
# ----------
# Resume Name:  data_analyst_resume_26
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  56
# ----------
# Resume Name:  data_analyst_resume_27
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  50
# ----------
# Resume Name:  data_analyst_resume_28
# JD Name:  jd_data\dataanalyst2_kaplan
# Matching Score:  53
# ----------
# Resume Name:  data_engineer_resume_40
# JD Name:  jd_data\de4_idexcel
# Matching Score:  56
# ----------
# Resume Name:  data_engineer_resume_41
# JD Name:  jd_data\de4_idexcel
# Matching Score:  48
# ----------
# Resume Name:  data_engineer_resume_42
# JD Name:  jd_data\de2_genpact
# Matching Score:  44
# ----------
# Resume Name:  data_engineer_resume_43
# JD Name:  jd_data\de4_idexcel
# Matching Score:  45
# ----------
# Resume Name:  data_engineer_resume_44
# JD Name:  jd_data\de2_genpact
# Matching Score:  38
# ----------
# Resume Name:  data_engineer_resume_45
# JD Name:  jd_data\de4_idexcel
# Matching Score:  55
# ----------
# Resume Name:  data_engineer_resume_46
# JD Name:  jd_data\de2_genpact
# Matching Score:  51
# ----------
# Resume Name:  data_engineer_resume_47
# JD Name:  jd_data\de4_idexcel
# Matching Score:  44
# ----------
# Resume Name:  data_engineer_resume_48
# JD Name:  jd_data\de2_genpact
# Matching Score:  53
# ----------
# Resume Name:  data_engineer_resume_49
# JD Name:  jd_data\de4_idexcel
# Matching Score:  51
# ----------
# Resume Name:  data_engineer_resume_50
# JD Name:  jd_data\de4_idexcel
# Matching Score:  50
# ----------
# Resume Name:  data_engineer_resume_51
# JD Name:  jd_data\de4_idexcel
# Matching Score:  56
# ----------
# Resume Name:  data_engineer_resume_52
# JD Name:  jd_data\de4_idexcel
# Matching Score:  50
# ----------
# Resume Name:  data_engineer_resume_53
# JD Name:  jd_data\de4_idexcel
# Matching Score:  52
# ----------
# Resume Name:  data_scientist_resume_54
# JD Name:  jd_data\ds4_amazon
# Matching Score:  55
# ----------
# Resume Name:  data_scientist_resume_55
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  44
# ----------
# Resume Name:  data_scientist_resume_56
# JD Name:  jd_data\ds4_amazon
# Matching Score:  49
# ----------
# Resume Name:  data_scientist_resume_57
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  52
# ----------
# Resume Name:  data_scientist_resume_58
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  53
# ----------
# Resume Name:  data_scientist_resume_59
# JD Name:  jd_data\ds4_amazon
# Matching Score:  44
# ----------
# Resume Name:  data_scientist_resume_60
# JD Name:  jd_data\ds4_amazon
# Matching Score:  40
# ----------
# Resume Name:  data_scientist_resume_61
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  45
# ----------
# Resume Name:  data_scientist_resume_62
# JD Name:  jd_data\ds4_amazon
# Matching Score:  49
# ----------
# Resume Name:  data_scientist_resume_63
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  54
# ----------
# Resume Name:  data_scientist_resume_64
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  48
# ----------
# Resume Name:  data_scientist_resume_65
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  51
# ----------
# Resume Name:  data_scientist_resume_66
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  56
# ----------
# Resume Name:  data_scientist_resume_67
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  44
# ----------
# Resume Name:  data_scientist_resume_68
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  43
# ----------
# Resume Name:  data_scientist_resume_69
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  47
# ----------
# Resume Name:  data_scientist_resume_70
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  54
# ----------
# Resume Name:  data_scientist_resume_71
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  54
# ----------
# Resume Name:  data_scientist_resume_72
# JD Name:  jd_data\ds3_lenovo
# Matching Score:  49
# ----------
# Resume Name:  machine_learning_engineer_resume_73
# JD Name:  jd_data\mle1_allianz
# Matching Score:  52
# ----------
# Resume Name:  machine_learning_engineer_resume_74
# JD Name:  jd_data\mle1_allianz
# Matching Score:  61
# ----------
# Resume Name:  machine_learning_engineer_resume_75
# JD Name:  jd_data\mle1_allianz
# Matching Score:  60
# ----------
# Resume Name:  machine_learning_engineer_resume_76
# JD Name:  jd_data\mle1_allianz
# Matching Score:  59
# ----------
# Resume Name:  machine_learning_engineer_resume_77
# JD Name:  jd_data\mle1_allianz
# Matching Score:  59
# ----------
# Resume Name:  machine_learning_engineer_resume_78
# JD Name:  jd_data\mle1_allianz
# Matching Score:  56
# ----------
# Resume Name:  machine_learning_engineer_resume_79
# JD Name:  jd_data\mle1_allianz
# Matching Score:  45
# ----------
# Resume Name:  machine_learning_engineer_resume_80
# JD Name:  jd_data\mle1_allianz
# Matching Score:  53
# ----------
# Resume Name:  machine_learning_engineer_resume_81
# JD Name:  jd_data\mle1_allianz
# Matching Score:  48
# ----------
# Resume Name:  machine_learning_engineer_resume_82
# JD Name:  jd_data\mle1_allianz
# Matching Score:  54
# ----------
# Resume Name:  machine_learning_engineer_resume_83
# JD Name:  jd_data\mle1_allianz
# Matching Score:  58
# ----------
# Resume Name:  mlops_engineer_resume_84
# JD Name:  jd_data\mlops3_exela
# Matching Score:  47
# ----------
# Resume Name:  mlops_engineer_resume_85
# JD Name:  jd_data\mlops4_exl
# Matching Score:  60
# ----------
# Resume Name:  mlops_engineer_resume_86
# JD Name:  jd_data\mlops4_exl
# Matching Score:  54
# ----------
# Resume Name:  mlops_engineer_resume_87
# JD Name:  jd_data\mlops1_mindtree
# Matching Score:  51
# ----------
# Resume Name:  mlops_engineer_resume_88
# JD Name:  jd_data\mlops1_mindtree
# Matching Score:  46
# ----------

# %%
match_df = pd.DataFrame(output, columns=["resume_name", "jd_name", "matching_score"])

# %%
match_df.head(100)
# Out:
#                                 resume_name                   jd_name  \
# 0   business_intelligence_analyst_resume_10  jd_data\bianalyst3_nicbl
# 1   business_intelligence_analyst_resume_11  jd_data\bianalyst3_nicbl
# 2   business_intelligence_analyst_resume_12  jd_data\bianalyst3_nicbl
# 3   business_intelligence_analyst_resume_13  jd_data\bianalyst3_nicbl
# 4    business_intelligence_analyst_resume_4  jd_data\bianalyst3_nicbl
# ..                                      ...                       ...
# 83                 mlops_engineer_resume_84      jd_data\mlops3_exela
# 84                 mlops_engineer_resume_85        jd_data\mlops4_exl
# 85                 mlops_engineer_resume_86        jd_data\mlops4_exl
# 86                 mlops_engineer_resume_87   jd_data\mlops1_mindtree
# 87                 mlops_engineer_resume_88   jd_data\mlops1_mindtree
#
#     matching_score
# 0               54
# 1               55
# 2               56
# 3               50
# 4               52
# ..             ...
# 83              47
# 84              60
# 85              54
# 86              51
# 87              46
#
# [88 rows x 3 columns]
